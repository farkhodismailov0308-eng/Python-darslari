# %% [markdown]
# <a href="https://colab.research.google.com/github/farkhodismailov0308-eng/Python-darslari/blob/farkhodismailov0308-eng-patch-1/print('Hello%20World').ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World
