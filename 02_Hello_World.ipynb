# %% [markdown]
# <a href="https://colab.research.google.com/github/farkhodismailov0308-eng/Python-darslari/blob/farkhodismailov0308-eng-patch-1/02_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")

print('Assalomu Aleykum')

print('XAYRLI TONG!') #PRINT katta harflar bilan yozilmaydi! va matn qo'shtirnoq("_" yoki '_') ichida bo'lishi kerak.

print(2+4*2)

print(19/5)

print(2**4)
# Out:
# Hello World
# Assalomu Aleykum
# XAYRLI TONG!
# 10
# 3.8
# 16
